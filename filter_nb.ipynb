# %%
import numpy as np
import pandas as pd
import cv2
import keras
# Out:
# Using TensorFlow backend.

# %%
import matplotlib
import seaborn as sn

# %%
print(np.__version__)
print(pd.__version__)
print(cv2.__version__)
print(keras.__version__)

print(matplotlib.__version__)
print(sn.__version__)
# Out:
# 1.17.3
# 0.25.0
# 4.1.1
# 2.2.4
# 3.1.1
# 0.9.0

# %%
print("filter notebook")
# Out:
# filter notebook
